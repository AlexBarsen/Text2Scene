# %%
from collections import Counter
import spacy
import os
import glob
import xml.etree.ElementTree as et
import matplotlib.pyplot as plt
nlp = spacy.load("en_core_web_sm")

# %%
def calc(dir):
    
    spatial_entities = 0
    places = 0
    motions = 0
    qslinks = 0
    olinks = 0
    signals = 0
    values = []
    c_tokens = Counter()
    c_types = Counter()
    c_motion = Counter()
    c_qsl = Counter()
    c_ol = Counter()
    
    for file in os.listdir(dir):
        if file.endswith(".xml"):
            tree = et.parse(os.path.join(dir, file))
            root = tree.getroot()
            text = None
            for child in root:
                if child.tag == "TEXT":
                    doc = nlp(child.text)

                    # Wie oft kommen welche PoS-Tags vor?
                    c_t = Counter(([token.pos_ for token in doc]))
                    c_tokens = c_tokens + c_t

                    # Wie viele [SpatialEntities, Places, Motions, Signals, QsLinks, OLinks] gibt es?
                    c_se = Counter(([elem.tag for elem in root.iter("SPATIAL_ENTITY")]))
                    spatial_entities = spatial_entities + sum(c_se.values())

                    c_p = Counter(([elem.tag for elem in root.iter("PLACE")]))
                    places = places + sum(c_p.values())

                    c_m = Counter(([elem.tag for elem in root.iter("MOTION")]))
                    motions = motions + sum(c_m.values())

                    c_qs_link = Counter(([elem.tag for elem in root.iter("QSLINK")]))
                    qslinks = qslinks + sum(c_qs_link.values())

                    c_o_link = Counter(([elem.tag for elem in root.iter("OLINK")]))
                    olinks = olinks + sum(c_o_link.values())

                    # Signals = spatial signals + motion signals ?
                    c_s_s = Counter(([elem.tag for elem in root.iter("SPATIAL_SIGNAL")]))
                    c_m_s = Counter(([elem.tag for elem in root.iter("MOTION_SIGNAL")]))
                    c_s= sum(c_s_s.values()) + sum(c_m_s.values())
                    signals = signals + c_s

                    # Wie oft kommen welche QsLink Typen vor? (DC,EC, ...)?
                    c_qs_type =  Counter(([elem.get('relType') for elem in root.iter("QSLINK")]))
                    c_types = c_types + c_qs_type
                    
                    c_m =  Counter(([elem.get('text') for elem in root.iter("MOTION")]))
                    c_motion = c_motion + c_m
                    
                    # Welche Links (QSLINKS, OLINKS) werden von welchen Präpositionen (markiert durch SPATIAL_SIGNAL) getriggert?
                    triggers = []
                    for qslink in root.iter("QSLINK"):
                        if qslink.get("trigger") != "":
                            trigger = qslink.get("trigger"), qslink.get("id")
                            triggers.append(trigger)

                    for spatial_signal in root.iter("SPATIAL_SIGNAL"):
                        for i in range (len(triggers)):
                            if spatial_signal.get("id") in triggers[i]:
                                c_qsl.update([spatial_signal.get("text")])
                                
                    
                    triggers2 = []
                    for olink in root.iter("OLINK"):
                        if olink.get("trigger") != "":
                            trigger2 = olink.get("trigger"), olink.get("id")
                            triggers2.append(trigger2)

                    for spatial_signal in root.iter("SPATIAL_SIGNAL"):
                        for i in range (len(triggers2)):
                            if spatial_signal.get("id") in triggers2[i]:
                                c_ol.update([spatial_signal.get("text")])
                                
                    # Verteilung der Satzlänge graphisch darstellen (x: Satzlänge, y: Wie häufig)?
                    sentences = list(doc.sents)

                    # Häufigkeit von Sätzen 
                    for i in range(0, len(sentences)):
                        values.append(len(sentences[i]))

    return c_tokens, spatial_entities, places, motions, qslinks, olinks, signals, values, c_types, c_motion, c_qsl, c_ol

# %%
c_tokens1, spatial_entities1, places1, motions1, qslinks1, olinks1, signals1, values1, c_types1, c_motion1, c_qsl1, c_ol1 = calc("./CP")
c_tokens2, spatial_entities2, places2, motions2, qslinks2, olinks2, signals2, values2, c_types2, c_motion2, c_qsl2, c_ol2 = calc("./RFC")
c_tokens3, spatial_entities3, places3, motions3, qslinks3, olinks3, signals3, values3, c_types3, c_motion3, c_qsl3, c_ol3 = calc("./ANC/WhereToJapan")
c_tokens4, spatial_entities4, places4, motions4, qslinks4, olinks4, signals4, values4, c_types4, c_motion4, c_qsl4, c_ol4 = calc("./ANC/WhereToMadrid")

c_tokens = c_tokens1 + c_tokens2 + c_tokens3 + c_tokens4
spatial_entities = spatial_entities1 + spatial_entities2 + spatial_entities3 + spatial_entities4
places = places1 + places2 + places3 + places4
motions = motions1 + motions2 + motions3 + motions4
qslinks = qslinks1 + qslinks2 + qslinks3 + qslinks4
olinks = olinks1 + olinks2 + olinks3 + olinks4
signals = signals1 + signals2 + signals3 + signals4
values = values1 + values2 + values3 + values4
c_types = c_types1 + c_types2 + c_types3 + c_types4
c_motion = c_motion1 + c_motion2 + c_motion3 + c_motion4
c_qsl = c_qsl1 + c_qsl2 + c_qsl3 + c_qsl4
c_ol = c_ol1 + c_ol2 + c_ol3 + c_ol4

# %%
for tag, count in c_tokens.items():
    print(tag, "=", count)
print("Es gibt =" , spatial_entities, "Spatial Entities")
print("Es gibt =" , places , "Places")
print("Es gibt =" , motions, "Motions")
print("Es gibt =" , signals, "Signals")
print("Es gibt =" , qslinks, "QsLinks")
print("Es gibt =" , olinks, "OLinks")
for typ, count in c_types.items():
    print(typ, "=", count)
for motions, count in c_motion.most_common(5):
    print(motions, count, sep=': ')
for signal, count in c_qsl.items():
    print("QSLINK wurde", count, "mal von", signal, "getirggert")
for signal, count in c_ol.items():
    print("OLink wurde", count, "mal von", signal, "getirggert")
# Out:
# SPACE = 825
# PROPN = 2095
# PUNCT = 3501
# ADP = 3005
# ADJ = 1781
# NUM = 683
# CCONJ = 825
# PRON = 1362
# VERB = 2721
# DET = 3203
# NOUN = 5030
# ADV = 1326
# AUX = 1035
# PART = 491
# SCONJ = 431
# X = 30
# SYM = 28
# INTJ = 10
# Es gibt = 1417 Spatial Entities
# Es gibt = 1852 Places
# Es gibt = 771 Motions
# Es gibt = 1240 Signals
# Es gibt = 970 QsLinks
# Es gibt = 244 OLinks
# EQ = 35
# EC = 196
# IN = 586
# NTPP = 42
# DC = 41
# TPP = 53
# PO = 12
# OUT = 3
#  = 2
# biked: 22
# visited: 21
# biking: 16
# go: 15
# bike: 15
# QSLINK wurde 75 mal von on getirggert
# QSLINK wurde 6 mal von At getirggert
# QSLINK wurde 2 mal von to getirggert
# QSLINK wurde 22 mal von In getirggert
# QSLINK wurde 228 mal von in getirggert
# QSLINK wurde 68 mal von where getirggert
# QSLINK wurde 1 mal von beside getirggert
# QSLINK wurde 4 mal von through getirggert
# QSLINK wurde 54 mal von at getirggert
# QSLINK wurde 44 mal von of getirggert
# QSLINK wurde 3 mal von far from getirggert
# QSLINK wurde 4 mal von away from getirggert
# QSLINK wurde 1 mal von behind getirggert
# QSLINK wurde 1 mal von Along getirggert
# QSLINK wurde 5 mal von covered getirggert
# QSLINK wurde 1 mal von inhabited getirggert
# QSLINK wurde 1 mal von apart from getirggert
# QSLINK wurde 1 mal von coiling up getirggert
# QSLINK wurde 1 mal von into getirggert
# QSLINK wurde 1 mal von about getirggert
# QSLINK wurde 10 mal von next to getirggert
# QSLINK wurde 4 mal von around getirggert
# QSLINK wurde 1 mal von after getirggert
# QSLINK wurde 1 mal von on top of getirggert
# QSLINK wurde 1 mal von inside of getirggert
# QSLINK wurde 4 mal von On getirggert
# QSLINK wurde 1 mal von in front of getirggert
# QSLINK wurde 14 mal von along getirggert
# QSLINK wurde 1 mal von up getirggert
# QSLINK wurde 1 mal von further getirggert
# QSLINK wurde 2 mal von under getirggert
# QSLINK wurde 15 mal von with getirggert
# QSLINK wurde 1 mal von In front of getirggert
# QSLINK wurde 2 mal von over getirggert
# QSLINK wurde 5 mal von between getirggert
# QSLINK wurde 10 mal von full of getirggert
# QSLINK wurde 2 mal von away getirggert
# QSLINK wurde 2 mal von outside getirggert
# QSLINK wurde 1 mal von Everywhere getirggert
# QSLINK wurde 2 mal von overlooking getirggert
# QSLINK wurde 3 mal von including getirggert
# QSLINK wurde 1 mal von stocked getirggert
# QSLINK wurde 2 mal von on top getirggert
# QSLINK wurde 2 mal von across getirggert
# QSLINK wurde 3 mal von from getirggert
# QSLINK wurde 2 mal von surrounded getirggert
# QSLINK wurde 1 mal von out of getirggert
# QSLINK wurde 3 mal von filled getirggert
# QSLINK wurde 1 mal von contains getirggert
# QSLINK wurde 2 mal von atop getirggert
# QSLINK wurde 3 mal von surrounding getirggert
# QSLINK wurde 1 mal von line getirggert
# QSLINK wurde 1 mal von packed getirggert
# QSLINK wurde 1 mal von afar getirggert
# QSLINK wurde 2 mal von has getirggert
# QSLINK wurde 1 mal von directly beneath getirggert
# QSLINK wurde 4 mal von inside getirggert
# QSLINK wurde 1 mal von for getirggert
# QSLINK wurde 1 mal von apart getirggert
# QSLINK wurde 1 mal von up to getirggert
# QSLINK wurde 1 mal von Down getirggert
# QSLINK wurde 1 mal von upon getirggert
# QSLINK wurde 1 mal von covering getirggert
# QSLINK wurde 1 mal von restricted getirggert
# QSLINK wurde 11 mal von houses getirggert
# QSLINK wurde 4 mal von contain getirggert
# QSLINK wurde 1 mal von adjacent to getirggert
# QSLINK wurde 1 mal von packed with getirggert
# QSLINK wurde 1 mal von surmounted getirggert
# QSLINK wurde 1 mal von house getirggert
# QSLINK wurde 1 mal von bordering getirggert
# QSLINK wurde 4 mal von connects getirggert
# QSLINK wurde 1 mal von against getirggert
# QSLINK wurde 1 mal von part         of getirggert
# OLink wurde 1 mal von southwest getirggert
# OLink wurde 1 mal von toward getirggert
# OLink wurde 2 mal von south of getirggert
# OLink wurde 1 mal von beside getirggert
# OLink wurde 14 mal von along getirggert
# OLink wurde 3 mal von behind getirggert
# OLink wurde 1 mal von in the direction to getirggert
# OLink wurde 1 mal von Along getirggert
# OLink wurde 5 mal von covered getirggert
# OLink wurde 45 mal von on getirggert
# OLink wurde 5 mal von up getirggert
# OLink wurde 3 mal von to getirggert
# OLink wurde 1 mal von to SW getirggert
# OLink wurde 1 mal von to the west from getirggert
# OLink wurde 1 mal von coiling up getirggert
# OLink wurde 1 mal von on the right getirggert
# OLink wurde 12 mal von next to getirggert
# OLink wurde 1 mal von on top of getirggert
# OLink wurde 2 mal von in front of getirggert
# OLink wurde 2 mal von On getirggert
# OLink wurde 1 mal von backwards getirggert
# OLink wurde 2 mal von Down getirggert
# OLink wurde 3 mal von under getirggert
# OLink wurde 3 mal von around getirggert
# OLink wurde 1 mal von in that direction getirggert
# OLink wurde 1 mal von In front of getirggert
# OLink wurde 1 mal von on your left getirggert
# OLink wurde 7 mal von over getirggert
# OLink wurde 8 mal von between getirggert
# OLink wurde 1 mal von northeast getirggert
# OLink wurde 2 mal von north getirggert
# OLink wurde 3 mal von of getirggert
# OLink wurde 1 mal von neighboring getirggert
# OLink wurde 5 mal von down getirggert
# OLink wurde 3 mal von overlooking getirggert
# OLink wurde 2 mal von on top getirggert
# OLink wurde 4 mal von surrounded getirggert
# OLink wurde 4 mal von above getirggert
# OLink wurde 4 mal von south getirggert
# OLink wurde 2 mal von atop getirggert
# OLink wurde 3 mal von surrounding getirggert
# OLink wurde 1 mal von line getirggert
# OLink wurde 4 mal von below getirggert
# OLink wurde 4 mal von beneath getirggert
# OLink wurde 1 mal von directly beneath getirggert
# OLink wurde 1 mal von across getirggert
# OLink wurde 2 mal von in getirggert
# OLink wurde 1 mal von up to getirggert
# OLink wurde 1 mal von upstream from getirggert
# OLink wurde 1 mal von upon getirggert
# OLink wurde 1 mal von overlook getirggert
# OLink wurde 3 mal von east of getirggert
# OLink wurde 1 mal von to the left getirggert
# OLink wurde 1 mal von facing getirggert
# OLink wurde 1 mal von West of getirggert
# OLink wurde 1 mal von South­east of getirggert
# OLink wurde 1 mal von adjacent to getirggert
# OLink wurde 1 mal von surmounted getirggert
# OLink wurde 2 mal von east getirggert
# OLink wurde 1 mal von Across getirggert
# OLink wurde 1 mal von alongside getirggert
# OLink wurde 1 mal von across from getirggert
# OLink wurde 1 mal von west getirggert
# OLink wurde 2 mal von north of getirggert
# OLink wurde 1 mal von Facing getirggert
# OLink wurde 1 mal von next door to getirggert
# OLink wurde 2 mal von Southeast of getirggert

# %%
plt.hist(values, bins = max(values))

# Titel und Axis-Namen
plt.xlabel('Satzlänge')
plt.ylabel('Wie häufig?')

plt.show()

# %%
import networkx as nx
# %matplotlib inline

# %%
# ich hoffe so was wurde gemeint bei dieser Übung
def vis(dir, save):
    tree = et.parse(dir)
    root = tree.getroot()
    G=nx.Graph()

    ids = []
    labeldict= {}
    for elem in root.iter("PLACE"):
        ids.append(elem.get("id"))
    #     G.add_node(elem.get("text"))

    for elem in root.iter("SPATIAL_ENTITY"):
        ids.append(elem.get("id"))
    #     G.add_node(elem.get("text"))
    
    labeldict= {}
    for elem in root.iter("METALINK"):
        if elem.get("fromID") in ids:
            if elem.get("toID") in ids:
                G.add_node(elem.get("toText"))
                labeldict[elem.get("toText")]= elem.get("toText")
            

    for elem in root.iter("QSLINK"):
        if elem.get("fromID") in ids:
            if elem.get("toID") in ids:
                G.add_edge(elem.get("fromText"), elem.get("toText"))
                labeldict[elem.get("toText")]= elem.get("relType")
            
    for elem in root.iter("OLINK"):
        if elem.get("fromID") in ids:
            if elem.get("toID") in ids:
                G.add_edge(elem.get("fromText"), elem.get("toText"))
                labeldict[elem.get("toText")]= elem.get("relType")
    
    nx.draw(G, labels =labeldict, with_labels = True)
    plt.rcParams['figure.figsize'] = [15, 10]
    plt.savefig(save)
    plt.show()

# %%
vis("./RFC/Bicycles.xml", "bicylces_graph.png")
vis("./ANC/WhereToMadrid/Highlights_of_the_Prado_Museum.xml", "Highlights_of_the_Prado_Museum_graph.png")
